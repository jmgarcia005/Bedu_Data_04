# %%
# Importing Data

import pandas as pd

FILENAME = 'datasets/best_sellers.csv'

# Reading a CSV file using pandas
df = pd.read_csv(FILENAME)
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# 0  Little, Brown                  THE HOST  5b4aa4ead3089013507db18c
# 1   St. Martin's  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2         Putnam                 THE FRONT  5b4aa4ead3089013507db18e
# 3      Doubleday                     SNUFF  5b4aa4ead3089013507db18f
# 4         Putnam              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
# 3         2008-05-24 00:00:00              1212883200000              5
# 4         2008-05-24 00:00:00              1212883200000              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         4                        3               26.95

# %%
df['description'].str.replace('Descr: ','')
# Out:
# 0       Aliens have taken control of the minds and bod...
# 1       A woman's happy marriage is shaken when she en...
# 2       A Massachusetts state investigator and his tea...
# 3       An aging porn queens aims to cap her career by...
# 4       The Minneapolis detective Lucas Davenport inve...
#                               ...
# 2261    The New York lawyer Stone Barrington discovers...
# 2262    Jake Fisher discovers that neither the woman h...
# 2263    Six friends meet in the 1970s at a summer arts...
# 2264    Bernie Gunther, the Berlin cop, is sent to Smo...
# 2265    A New Hampshire baker finds herself in the mid...
# Name: description, Length: 2266, dtype: object

# %%
df['description'] = df['description'].str.replace('Descr: ','')
df.loc[0,'description']
# Out:
# 'Aliens have taken control of the minds and bodies of most humans, but one woman won’t surrender.     '

# %%
df['description'] = df['description'].str.replace('Descr: ','')
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Aliens have taken control of the minds and bod...
# 1       Emily Giffin  A woman's happy marriage is shaken when she en...
# 2  Patricia Cornwell  A Massachusetts state investigator and his tea...
# 3    Chuck Palahniuk  An aging porn queens aims to cap her career by...
# 4      John Sandford  The Minneapolis detective Lucas Davenport inve...
#
#        publisher                     title                       oid  \
# 0  Little, Brown                  THE HOST  5b4aa4ead3089013507db18c
# 1   St. Martin's  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2         Putnam                 THE FRONT  5b4aa4ead3089013507db18e
# 3      Doubleday                     SNUFF  5b4aa4ead3089013507db18f
# 4         Putnam              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
# 3         2008-05-24 00:00:00              1212883200000              5
# 4         2008-05-24 00:00:00              1212883200000              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 4                         4                        3               26.95

# %%
df['description'] = df['description'].str.strip()
df.loc[0,'description']
# Out:
# 'Aliens have taken control of the minds and bodies of most humans, but one woman won’t surrender.'

# %%
df['author'].str.strip[' ']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1911493dd93d> in <module>
# ----> 1 df['author'].str.strip[' ']
#
# TypeError: 'method' object is not subscriptable
